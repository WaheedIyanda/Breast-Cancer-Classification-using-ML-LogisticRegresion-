# %% [markdown]
# # Breast Cancer classification project

# %% [markdown]
# # Importing of required Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# # importing dataSet

# %%
BC_Data= pd.read_csv('breast cancer data.csv')
BC_Data.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
BC_Data.tail(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 559  925291         B        11.51         23.93           74.52      403.5
# 560  925292         B        14.05         27.15           91.38      600.4
# 561  925311         B        11.20         29.37           70.67      386.0
# 562  925622         M        15.22         30.62          103.40      716.9
# 563  926125         M        20.92         25.09          143.00     1347.0
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
#Data overview
BC_Data.info()
BC_Data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
BC_Data['Unnamed: 32']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 564   NaN
# 565   NaN
# 566   NaN
# 567   NaN
# 568   NaN
# Name: Unnamed: 32, Length: 569, dtype: float64

# %% [markdown]
# # i need to remove the Unnamed : 32 column, before futher processing of the data because it is an NaN

# %%
breast_cancer= BC_Data.iloc[:, :-1]
breast_cancer.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
breast_cancer.shape
# Out:
# (569, 32)

# %% [markdown]
# # simple data analysis

# %%
sns.histplot(BC_Data['diagnosis'])
# Out:
# <Axes: xlabel='diagnosis', ylabel='Count'>

# %%
sns.scatterplot(x=breast_cancer['radius_mean'], y=breast_cancer['texture_mean'])
plt.xlabel('Radius Mean')
plt.ylabel('Texture Mean')
plt.title('Scatter Plot: Radius Mean vs. Texture Mean')
plt.show()

# %%
sns.boxplot(x='diagnosis', y='radius_mean', data=breast_cancer)
plt.xlabel('Diagnosis')
plt.ylabel('Radius Mean')
plt.title('Diagnosis vs. Radius Mean')
plt.show()

# %%
correlation_matrix = breast_cancer.corr()

# Print correlation matrix
print(correlation_matrix)
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %%
breastcancer_mean = breast_cancer.groupby(breast_cancer['diagnosis']).mean()
breastcancer_mean
# Out:
#                      id  radius_mean  texture_mean  perimeter_mean  \
# diagnosis
# B          2.654382e+07    12.146524     17.914762       78.075406
# M          3.681805e+07    17.462830     21.604906      115.365377
#
#             area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# B          462.790196         0.092478          0.080085        0.046058
# M          978.376415         0.102898          0.145188        0.160775
#
#            concave points_mean  symmetry_mean  ...  radius_worst  \
# diagnosis                                      ...
# B                     0.025717       0.174186  ...     13.379801
# M                     0.087990       0.192909  ...     21.134811
#
#            texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# diagnosis
# B              23.515070        87.005938   558.899440          0.124959
# M              29.318208       141.370330  1422.286321          0.144845
#
# ...

# %% [markdown]
# # model training and Data Preprocessing

# %%
breast_cancer.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
b_cancer= breast_cancer.drop(['diagnosis', 'id'], axis=1)

# %%
b_cancer.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
X=b_cancer
y= breast_cancer['diagnosis']

# %%
#importing test-train model

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
print(X.shape, X_train.shape , X_test.shape)
# Out:
# (569, 30) (381, 30) (188, 30)

# %% [markdown]
# so, out of 569 data, 381 will be use to train the model and 188 will be used to test the model

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

b_model = LogisticRegression(max_iter=1000)

# %%
b_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# # check out model training accuracy

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
bc_prediction = b_model.predict(X_test)

# %%
print (confusion_matrix (y_test, bc_prediction))
print(classification_report(y_test, bc_prediction))
# Out:
# [[116   1]
#  [  3  68]]
#               precision    recall  f1-score   support
#
#            B       0.97      0.99      0.98       117
#            M       0.99      0.96      0.97        71
#
#     accuracy                           0.98       188
#    macro avg       0.98      0.97      0.98       188
# weighted avg       0.98      0.98      0.98       188

# %%
print(accuracy_score(y_test, bc_prediction))
# Out:
# 0.9787234042553191

# %%
#Buiding a predictive system
inpute_data= (18.25,	19.98,	119.6,	1040,	0.09463,	0.109,	0.1127,	0.074,	0.1794,	0.05742,	0.4467,	0.7732,	3.18,	53.91,	0.004314,	0.01382,	0.02254,	0.01039,	0.01369,	0.002179,	22.88,	27.66,	153.2,	1606,	0.1442,	0.2576,	0.3784,	0.1932,	0.3063,	0.08368)

# %%
inputeas_array= np.asarray(inpute_data)

# %%
inpute_reshape= inputeas_array.reshape(1,-1)

# %%
inpute_reshape
# Out:
# array([[1.825e+01, 1.998e+01, 1.196e+02, 1.040e+03, 9.463e-02, 1.090e-01,
#         1.127e-01, 7.400e-02, 1.794e-01, 5.742e-02, 4.467e-01, 7.732e-01,
#         3.180e+00, 5.391e+01, 4.314e-03, 1.382e-02, 2.254e-02, 1.039e-02,
#         1.369e-02, 2.179e-03, 2.288e+01, 2.766e+01, 1.532e+02, 1.606e+03,
#         1.442e-01, 2.576e-01, 3.784e-01, 1.932e-01, 3.063e-01, 8.368e-02]])

# %%
prediction= b_model.predict(inpute_reshape)
print(prediction)
#Result
if prediction == 'B':
    print('Breast Cancer is Benign')
elif prediction == 'M':
    print('Breast Cancer is Malignant')
else:
    print('Not applicable')
# Out:
# ['M']
# Breast Cancer is Malignant
